# %% [markdown]
# ### Importar bibliotecas necessárias

# %%
import pandas as pd
import requests
import json
import os

# %% [markdown]
# ### Caminho do projeto

# %%
path_data = './resumos_alt/'

# Verifica os diretórios que estiverem ausentes e os cria
if not os.path.exists(path_data):
    os.makedirs(path_data)

# %% [markdown]
# ### Entrada de dados
#
# - Entrada com a chave de API retirada da base de dados Scopus
# - Palavras-chave para a pesquisa na editora

# %%
# Chave pessoal, portanto, não disponibilizada
MY_API_KEY = " "
user_query = "TITLE-ABS-KEY ( 'pedrogao AND grande' ) AND PUBYEAR > 2016 AND PUBYEAR < 2024"

# %% [markdown]
# ### Impressão do Json a ser retirado da API
#
# - Função que permite a formatação dos dados através de suas hierarquias

# %%
def jprint(obj):
    text = json.dumps(obj, sort_keys=True, indent=6)
    print(text)

# %% [markdown]
# ## Pesquisa e recolha de resultados com a API Scoupus
#
# - É necessário acesso à API

# %%
headers = {
           'Accept':'application/json',
           'X-ELS-APIKey': MY_API_KEY
          }
params={
        'query' : user_query, 
        'language' : 'ENG'
       }

response = requests.get("https://api.elsevier.com/content/search/scopus", 
                        headers=headers, params=params)

print("URL de pesquisa: ",response.url)
print("Código de status: ",response.status_code)
# Out:
# URL de pesquisa:  https://api.elsevier.com/content/search/scopus?query=TITLE-ABS-KEY+%28+%27pedrogao+AND+grande%27+%29+AND+PUBYEAR+%3E+2016+AND+PUBYEAR+%3C+2024&language=ENG
# Código de status:  200

# %% [markdown]
# ### Normalizar os dados em forma hierarquica

# %%
results = response.json()
jprint(response.json())
# Out:
# {
#       "search-results": {
#             "entry": [
#                   {
#                         "@_fa": "true",
#                         "affiliation": [
#                               {
#                                     "@_fa": "true",
#                                     "affiliation-city": "Potenza",
#                                     "affiliation-country": "Italy",
#                                     "affilname": "Universit\u00e0 degli Studi della Basilicata"
#                               }
#                         ],
#                         "article-number": "133",
#                         "citedby-count": "0",
#                         "dc:creator": "Leone V.",
#                         "dc:identifier": "SCOPUS_ID:85154552372",
#                         "dc:title": "The 2017 Extreme Wildfires Events in Portugal through the Perceptions of Volunteer and Professional Firefighters",
#                         "eid": "2-s2.0-85154552372",
#                         "freetoread": {
#                               "value": [
#                                     {
#                                           "$": "all"
#                                     },
#                                     {
#                                           "$": "publisherfullgold"
#                                     }
#                               ]
#                         },
#                         "freetoreadLabel": {
#                               "value": [
#                                     {
#                                           "$": "All Open Access"
#                                     },
#                                     {
#                                           "$": "Gold"
#                                     }
#                               ]
#                         },
#                         "link": [
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/abstract/scopus_id/85154552372",
#                                     "@ref": "self"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/abstract/scopus_id/85154552372?field=author,affiliation",
#                                     "@ref": "author-affiliation"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85154552372&origin=inward",
#                                     "@ref": "scopus"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85154552372&origin=inward",
#                                     "@ref": "scopus-citedby"
#                               }
#                         ],
#                         "openaccess": "1",
#                         "openaccessFlag": true,
#                         "prism:aggregationType": "Journal",
#                         "prism:coverDate": "2023-04-01",
#                         "prism:coverDisplayDate": "April 2023",
#                         "prism:doi": "10.3390/fire6040133",
#                         "prism:eIssn": "25716255",
#                         "prism:issueIdentifier": "4",
#                         "prism:pageRange": null,
#                         "prism:publicationName": "Fire",
#                         "prism:url": "https://api.elsevier.com/content/abstract/scopus_id/85154552372",
#                         "prism:volume": "6",
#                         "source-id": "21101020133",
#                         "subtype": "ar",
#                         "subtypeDescription": "Article"
#                   },
#                   {
#                         "@_fa": "true",
#                         "affiliation": [
#                               {
#                                     "@_fa": "true",
#                                     "affiliation-city": "Vila Real",
#                                     "affiliation-country": "Portugal",
#                                     "affilname": "Centro de Investiga\u00e7\u00e3o e de Tecnologias Agroambientais e Biol\u00f3gicas"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "affiliation-city": "Tomar",
#                                     "affiliation-country": "Portugal",
#                                     "affilname": "Instituto Polit\u00e9cnico de Tomar"
#                               }
#                         ],
#                         "article-number": "56",
#                         "citedby-count": "2",
#                         "dc:creator": "Andrade C.",
#                         "dc:identifier": "SCOPUS_ID:85148738722",
#                         "dc:title": "Multi-Indices Diagnosis of the Conditions That Led to the Two 2017 Major Wildfires in Portugal",
#                         "eid": "2-s2.0-85148738722",
#                         "freetoread": {
#                               "value": [
#                                     {
#                                           "$": "all"
#                                     },
#                                     {
#                                           "$": "publisherfullgold"
#                                     },
#                                     {
#                                           "$": "repository"
#                                     },
#                                     {
#                                           "$": "repositoryvor"
#                                     }
#                               ]
#                         },
#                         "freetoreadLabel": {
#                               "value": [
#                                     {
#                                           "$": "All Open Access"
#                                     },
#                                     {
#                                           "$": "Gold"
#                                     },
#                                     {
#                                           "$": "Green"
#                                     }
#                               ]
#                         },
#                         "link": [
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/abstract/scopus_id/85148738722",
#                                     "@ref": "self"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/abstract/scopus_id/85148738722?field=author,affiliation",
#                                     "@ref": "author-affiliation"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85148738722&origin=inward",
#                                     "@ref": "scopus"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85148738722&origin=inward",
#                                     "@ref": "scopus-citedby"
#                               }
#                         ],
#                         "openaccess": "1",
#                         "openaccessFlag": true,
#                         "prism:aggregationType": "Journal",
#                         "prism:coverDate": "2023-02-01",
#                         "prism:coverDisplayDate": "February 2023",
#                         "prism:doi": "10.3390/fire6020056",
#                         "prism:eIssn": "25716255",
#                         "prism:issueIdentifier": "2",
#                         "prism:pageRange": null,
#                         "prism:publicationName": "Fire",
#                         "prism:url": "https://api.elsevier.com/content/abstract/scopus_id/85148738722",
#                         "prism:volume": "6",
#                         "source-id": "21101020133",
#                         "subtype": "ar",
#                         "subtypeDescription": "Article"
#                   },
#                   {
#                         "@_fa": "true",
#                         "affiliation": [
#                               {
#                                     "@_fa": "true",
#                                     "affiliation-city": "Coimbra",
#                                     "affiliation-country": "Portugal",
#                                     "affilname": "Association for the Development of Industrial Aerodynamic"
#                               }
#                         ],
#                         "citedby-count": "1",
#                         "dc:creator": "Viegas D.X.",
#                         "dc:identifier": "SCOPUS_ID:85164314098",
#                         "dc:title": "Field and laboratory analysis of the junction fire process in the catastrophic fire of Pedr\u00f3g\u00e3o Grande in June 2017",
#                         "eid": "2-s2.0-85164314098",
#                         "link": [
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/abstract/scopus_id/85164314098",
#                                     "@ref": "self"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/abstract/scopus_id/85164314098?field=author,affiliation",
#                                     "@ref": "author-affiliation"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85164314098&origin=inward",
#                                     "@ref": "scopus"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85164314098&origin=inward",
#                                     "@ref": "scopus-citedby"
#                               }
#                         ],
#                         "openaccess": "0",
#                         "openaccessFlag": false,
#                         "prism:aggregationType": "Journal",
#                         "prism:coverDate": "2023-01-01",
#                         "prism:coverDisplayDate": "2023",
#                         "prism:doi": "10.1071/WF22161",
#                         "prism:issn": "10498001",
#                         "prism:issueIdentifier": "6",
#                         "prism:pageRange": "951-967",
#                         "prism:publicationName": "International Journal of Wildland Fire",
#                         "prism:url": "https://api.elsevier.com/content/abstract/scopus_id/85164314098",
#                         "prism:volume": "32",
#                         "source-id": "28866",
#                         "subtype": "cp",
#                         "subtypeDescription": "Conference Paper"
#                   },
#                   {
#                         "@_fa": "true",
#                         "affiliation": [
#                               {
#                                     "@_fa": "true",
#                                     "affiliation-city": "Lisbon",
#                                     "affiliation-country": "Portugal",
#                                     "affilname": "Nova School of Business and Economics, Universidade Nova de Lisboa"
#                               }
#                         ],
#                         "citedby-count": "7",
#                         "dc:creator": "Cunha M.P.",
#                         "dc:identifier": "SCOPUS_ID:85129178367",
#                         "dc:title": "Myopia during emergency improvisation: lessons from a catastrophic wildfire",
#                         "eid": "2-s2.0-85129178367",
#                         "freetoread": {
#                               "value": [
#                                     {
#                                           "$": "all"
#                                     },
#                                     {
#                                           "$": "repository"
#                                     },
#                                     {
#                                           "$": "repositoryvor"
#                                     },
#                                     {
#                                           "$": "repositoryam"
#                                     }
#                               ]
#                         },
#                         "freetoreadLabel": {
#                               "value": [
#                                     {
#                                           "$": "All Open Access"
#                                     },
#                                     {
#                                           "$": "Green"
#                                     }
#                               ]
#                         },
#                         "link": [
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/abstract/scopus_id/85129178367",
#                                     "@ref": "self"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/abstract/scopus_id/85129178367?field=author,affiliation",
#                                     "@ref": "author-affiliation"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85129178367&origin=inward",
#                                     "@ref": "scopus"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85129178367&origin=inward",
#                                     "@ref": "scopus-citedby"
#                               }
#                         ],
#                         "openaccess": "0",
#                         "openaccessFlag": false,
#                         "prism:aggregationType": "Journal",
#                         "prism:coverDate": "2022-07-19",
#                         "prism:coverDisplayDate": "19 July 2022",
#                         "prism:doi": "10.1108/MD-03-2021-0378",
#                         "prism:issn": "00251747",
#                         "prism:issueIdentifier": "7",
#                         "prism:pageRange": "2019-2041",
#                         "prism:publicationName": "Management Decision",
#                         "prism:url": "https://api.elsevier.com/content/abstract/scopus_id/85129178367",
#                         "prism:volume": "60",
#                         "source-id": "144656",
#                         "subtype": "ar",
#                         "subtypeDescription": "Article"
#                   },
#                   {
#                         "@_fa": "true",
#                         "affiliation": [
#                               {
#                                     "@_fa": "true",
#                                     "affiliation-city": "Lisbon",
#                                     "affiliation-country": "Portugal",
#                                     "affilname": "Portuguese Institute for Sea and Atmosphere (IPMA)"
#                               }
#                         ],
#                         "article-number": "414",
#                         "citedby-count": "8",
#                         "dc:creator": "Pinto P.",
#                         "dc:identifier": "SCOPUS_ID:85126519355",
#                         "dc:title": "Influence of Convectively Driven Flows in the Course of a Large Fire in Portugal: The Case of Pedr\u00f3g\u00e3o Grande",
#                         "eid": "2-s2.0-85126519355",
#                         "freetoread": {
#                               "value": [
#                                     {
#                                           "$": "all"
#                                     },
#                                     {
#                                           "$": "publisherfullgold"
#                                     }
#                               ]
#                         },
#                         "freetoreadLabel": {
#                               "value": [
#                                     {
#                                           "$": "All Open Access"
#                                     },
#                                     {
#                                           "$": "Gold"
#                                     }
#                               ]
#                         },
#                         "link": [
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/abstract/scopus_id/85126519355",
#                                     "@ref": "self"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/abstract/scopus_id/85126519355?field=author,affiliation",
#                                     "@ref": "author-affiliation"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85126519355&origin=inward",
#                                     "@ref": "scopus"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85126519355&origin=inward",
#                                     "@ref": "scopus-citedby"
#                               }
#                         ],
#                         "openaccess": "1",
#                         "openaccessFlag": true,
#                         "prism:aggregationType": "Journal",
#                         "prism:coverDate": "2022-03-01",
#                         "prism:coverDisplayDate": "March 2022",
#                         "prism:doi": "10.3390/atmos13030414",
#                         "prism:eIssn": "20734433",
#                         "prism:issueIdentifier": "3",
#                         "prism:pageRange": null,
#                         "prism:publicationName": "Atmosphere",
#                         "prism:url": "https://api.elsevier.com/content/abstract/scopus_id/85126519355",
#                         "prism:volume": "13",
#                         "source-id": "15838",
#                         "subtype": "ar",
#                         "subtypeDescription": "Article"
#                   },
#                   {
#                         "@_fa": "true",
#                         "affiliation": [
#                               {
#                                     "@_fa": "true",
#                                     "affiliation-city": "Vila Real",
#                                     "affiliation-country": "Portugal",
#                                     "affilname": "Centro de Investiga\u00e7\u00e3o e de Tecnologias Agroambientais e Biol\u00f3gicas"
#                               }
#                         ],
#                         "article-number": "28",
#                         "citedby-count": "3",
#                         "dc:creator": "Santos J.A.",
#                         "dc:identifier": "SCOPUS_ID:85125061474",
#                         "dc:title": "Sub-Hourly Precipitation Extremes in Mainland Portugal and Their Driving Mechanisms",
#                         "eid": "2-s2.0-85125061474",
#                         "freetoread": {
#                               "value": [
#                                     {
#                                           "$": "all"
#                                     },
#                                     {
#                                           "$": "publisherfullgold"
#                                     }
#                               ]
#                         },
#                         "freetoreadLabel": {
#                               "value": [
#                                     {
#                                           "$": "All Open Access"
#                                     },
#                                     {
#                                           "$": "Gold"
#                                     }
#                               ]
#                         },
#                         "link": [
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/abstract/scopus_id/85125061474",
#                                     "@ref": "self"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/abstract/scopus_id/85125061474?field=author,affiliation",
#                                     "@ref": "author-affiliation"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85125061474&origin=inward",
#                                     "@ref": "scopus"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85125061474&origin=inward",
#                                     "@ref": "scopus-citedby"
#                               }
#                         ],
#                         "openaccess": "1",
#                         "openaccessFlag": true,
#                         "prism:aggregationType": "Journal",
#                         "prism:coverDate": "2022-02-01",
#                         "prism:coverDisplayDate": "February 2022",
#                         "prism:doi": "10.3390/cli10020028",
#                         "prism:eIssn": "22251154",
#                         "prism:issueIdentifier": "2",
#                         "prism:pageRange": null,
#                         "prism:publicationName": "Climate",
#                         "prism:url": "https://api.elsevier.com/content/abstract/scopus_id/85125061474",
#                         "prism:volume": "10",
#                         "source-id": "21100826864",
#                         "subtype": "ar",
#                         "subtypeDescription": "Article"
#                   },
#                   {
#                         "@_fa": "true",
#                         "affiliation": [
#                               {
#                                     "@_fa": "true",
#                                     "affiliation-city": "Valladolid",
#                                     "affiliation-country": "Spain",
#                                     "affilname": "Universidad Europea Miguel de Cervantes"
#                               }
#                         ],
#                         "citedby-count": "0",
#                         "dc:creator": "Ortiz S.L.",
#                         "dc:identifier": "SCOPUS_ID:85126571661",
#                         "dc:title": "The informative coverage of tragic events into television channels. A case study: the Pedr\u00f3g\u00e3o Grande fires in Portugal and the disappearance of Jul\u00e9n Rosell\u00f3 in Spain",
#                         "eid": "2-s2.0-85126571661",
#                         "freetoread": {
#                               "value": [
#                                     {
#                                           "$": "all"
#                                     },
#                                     {
#                                           "$": "publisherfullgold"
#                                     }
#                               ]
#                         },
#                         "freetoreadLabel": {
#                               "value": [
#                                     {
#                                           "$": "All Open Access"
#                                     },
#                                     {
#                                           "$": "Gold"
#                                     }
#                               ]
#                         },
#                         "link": [
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/abstract/scopus_id/85126571661",
#                                     "@ref": "self"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/abstract/scopus_id/85126571661?field=author,affiliation",
#                                     "@ref": "author-affiliation"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85126571661&origin=inward",
#                                     "@ref": "scopus"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85126571661&origin=inward",
#                                     "@ref": "scopus-citedby"
#                               }
#                         ],
#                         "openaccess": "1",
#                         "openaccessFlag": true,
#                         "prism:aggregationType": "Journal",
#                         "prism:coverDate": "2021-01-01",
#                         "prism:coverDisplayDate": "2021",
#                         "prism:doi": "10.15847/obsOBS15420211963",
#                         "prism:eIssn": "16465954",
#                         "prism:issueIdentifier": "4",
#                         "prism:pageRange": "19-39",
#                         "prism:publicationName": "Observatorio",
#                         "prism:url": "https://api.elsevier.com/content/abstract/scopus_id/85126571661",
#                         "prism:volume": "15",
#                         "source-id": "19900188004",
#                         "subtype": "ar",
#                         "subtypeDescription": "Article"
#                   },
#                   {
#                         "@_fa": "true",
#                         "affiliation": [
#                               {
#                                     "@_fa": "true",
#                                     "affiliation-city": "Coimbra",
#                                     "affiliation-country": "Portugal",
#                                     "affilname": "Association for the Development of Industrial Aerodynamic"
#                               }
#                         ],
#                         "article-number": "57",
#                         "citedby-count": "25",
#                         "dc:creator": "Ribeiro L.M.",
#                         "dc:identifier": "SCOPUS_ID:85094572220",
#                         "dc:title": "The impact on structures of the pedr\u00f3g\u00e3o grande fire complex in June 2017 (Portugal)",
#                         "eid": "2-s2.0-85094572220",
#                         "freetoread": {
#                               "value": [
#                                     {
#                                           "$": "all"
#                                     },
#                                     {
#                                           "$": "publisherfullgold"
#                                     },
#                                     {
#                                           "$": "repository"
#                                     },
#                                     {
#                                           "$": "repositoryvor"
#                                     }
#                               ]
#                         },
#                         "freetoreadLabel": {
#                               "value": [
#                                     {
#                                           "$": "All Open Access"
#                                     },
#                                     {
#                                           "$": "Gold"
#                                     },
#                                     {
#                                           "$": "Green"
#                                     }
#                               ]
#                         },
#                         "link": [
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/abstract/scopus_id/85094572220",
#                                     "@ref": "self"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/abstract/scopus_id/85094572220?field=author,affiliation",
#                                     "@ref": "author-affiliation"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85094572220&origin=inward",
#                                     "@ref": "scopus"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85094572220&origin=inward",
#                                     "@ref": "scopus-citedby"
#                               }
#                         ],
#                         "openaccess": "1",
#                         "openaccessFlag": true,
#                         "prism:aggregationType": "Journal",
#                         "prism:coverDate": "2020-12-01",
#                         "prism:coverDisplayDate": "December 2020",
#                         "prism:doi": "10.3390/fire3040057",
#                         "prism:eIssn": "25716255",
#                         "prism:issueIdentifier": "4",
#                         "prism:pageRange": "1-22",
#                         "prism:publicationName": "Fire",
#                         "prism:url": "https://api.elsevier.com/content/abstract/scopus_id/85094572220",
#                         "prism:volume": "3",
#                         "source-id": "21101020133",
#                         "subtype": "ar",
#                         "subtypeDescription": "Article"
#                   },
#                   {
#                         "@_fa": "true",
#                         "affiliation": [
#                               {
#                                     "@_fa": "true",
#                                     "affiliation-city": "Evora",
#                                     "affiliation-country": "Portugal",
#                                     "affilname": "University of \u00c9vora"
#                               }
#                         ],
#                         "article-number": "104993",
#                         "citedby-count": "22",
#                         "dc:creator": "Couto F.T.",
#                         "dc:identifier": "SCOPUS_ID:85083397940",
#                         "dc:title": "Lightning modelling for the research of forest fire ignition in Portugal",
#                         "eid": "2-s2.0-85083397940",
#                         "link": [
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/abstract/scopus_id/85083397940",
#                                     "@ref": "self"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/abstract/scopus_id/85083397940?field=author,affiliation",
#                                     "@ref": "author-affiliation"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85083397940&origin=inward",
#                                     "@ref": "scopus"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85083397940&origin=inward",
#                                     "@ref": "scopus-citedby"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/article/eid/1-s2.0-S0169809519315005",
#                                     "@ref": "full-text"
#                               }
#                         ],
#                         "openaccess": "0",
#                         "openaccessFlag": false,
#                         "pii": "S0169809519315005",
#                         "prism:aggregationType": "Journal",
#                         "prism:coverDate": "2020-09-15",
#                         "prism:coverDisplayDate": "15 September 2020",
#                         "prism:doi": "10.1016/j.atmosres.2020.104993",
#                         "prism:issn": "01698095",
#                         "prism:pageRange": null,
#                         "prism:publicationName": "Atmospheric Research",
#                         "prism:url": "https://api.elsevier.com/content/abstract/scopus_id/85083397940",
#                         "prism:volume": "242",
#                         "source-id": "12092",
#                         "subtype": "ar",
#                         "subtypeDescription": "Article"
#                   },
#                   {
#                         "@_fa": "true",
#                         "affiliation": [
#                               {
#                                     "@_fa": "true",
#                                     "affiliation-city": "Covilha",
#                                     "affiliation-country": "Portugal",
#                                     "affilname": "Universidade da Beira Interior"
#                               }
#                         ],
#                         "citedby-count": "0",
#                         "dc:creator": "Toniolo B.P.",
#                         "dc:identifier": "SCOPUS_ID:85096701470",
#                         "dc:title": "When the sender is the message: the communication of Marcelo Rebelo de Sousa about the 2017 fires",
#                         "eid": "2-s2.0-85096701470",
#                         "freetoread": {
#                               "value": [
#                                     {
#                                           "$": "all"
#                                     },
#                                     {
#                                           "$": "publisherfullgold"
#                                     },
#                                     {
#                                           "$": "repository"
#                                     },
#                                     {
#                                           "$": "repositoryvor"
#                                     },
#                                     {
#                                           "$": "repositoryam"
#                                     }
#                               ]
#                         },
#                         "freetoreadLabel": {
#                               "value": [
#                                     {
#                                           "$": "All Open Access"
#                                     },
#                                     {
#                                           "$": "Gold"
#                                     },
#                                     {
#                                           "$": "Green"
#                                     }
#                               ]
#                         },
#                         "link": [
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/abstract/scopus_id/85096701470",
#                                     "@ref": "self"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/abstract/scopus_id/85096701470?field=author,affiliation",
#                                     "@ref": "author-affiliation"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85096701470&origin=inward",
#                                     "@ref": "scopus"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85096701470&origin=inward",
#                                     "@ref": "scopus-citedby"
#                               }
#                         ],
#                         "openaccess": "1",
#                         "openaccessFlag": true,
#                         "prism:aggregationType": "Journal",
#                         "prism:coverDate": "2020-07-30",
#                         "prism:coverDisplayDate": "30 July 2020",
#                         "prism:doi": "10.17231/comsoc.0(2020).2741",
#                         "prism:eIssn": "21833575",
#                         "prism:issn": "16452089",
#                         "prism:issueIdentifier": "Special Issue",
#                         "prism:pageRange": "69-88",
#                         "prism:publicationName": "Comunicacao e Sociedade",
#                         "prism:url": "https://api.elsevier.com/content/abstract/scopus_id/85096701470",
#                         "prism:volume": "2020",
#                         "source-id": "21100843261",
#                         "subtype": "ar",
#                         "subtypeDescription": "Article"
#                   },
#                   {
#                         "@_fa": "true",
#                         "affiliation": [
#                               {
#                                     "@_fa": "true",
#                                     "affiliation-city": "Saint Martin d'Heres",
#                                     "affiliation-country": "France",
#                                     "affilname": "Universit\u00e9 Grenoble Alpes"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "affiliation-city": "Bern",
#                                     "affiliation-country": "Switzerland",
#                                     "affilname": "University of Bern"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "affiliation-city": "Villigen",
#                                     "affiliation-country": "Switzerland",
#                                     "affilname": "Paul Scherrer Institut"
#                               }
#                         ],
#                         "citedby-count": "3",
#                         "dc:creator": "Osmont D.",
#                         "dc:identifier": "SCOPUS_ID:85105876022",
#                         "dc:title": "Tracing devastating fires in Portugal to a snow archive in the Swiss Alps: A case study",
#                         "eid": "2-s2.0-85105876022",
#                         "freetoread": {
#                               "value": [
#                                     {
#                                           "$": "all"
#                                     },
#                                     {
#                                           "$": "publisherfullgold"
#                                     },
#                                     {
#                                           "$": "repository"
#                                     },
#                                     {
#                                           "$": "repositoryvor"
#                                     }
#                               ]
#                         },
#                         "freetoreadLabel": {
#                               "value": [
#                                     {
#                                           "$": "All Open Access"
#                                     },
#                                     {
#                                           "$": "Gold"
#                                     },
#                                     {
#                                           "$": "Green"
#                                     }
#                               ]
#                         },
#                         "link": [
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/abstract/scopus_id/85105876022",
#                                     "@ref": "self"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/abstract/scopus_id/85105876022?field=author,affiliation",
#                                     "@ref": "author-affiliation"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85105876022&origin=inward",
#                                     "@ref": "scopus"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85105876022&origin=inward",
#                                     "@ref": "scopus-citedby"
#                               }
#                         ],
#                         "openaccess": "1",
#                         "openaccessFlag": true,
#                         "prism:aggregationType": "Journal",
#                         "prism:coverDate": "2020-01-01",
#                         "prism:coverDisplayDate": "2020",
#                         "prism:doi": "10.5194/tc-14-3731-2020",
#                         "prism:eIssn": "19940424",
#                         "prism:issn": "19940416",
#                         "prism:issueIdentifier": "11",
#                         "prism:pageRange": "3731-3745",
#                         "prism:publicationName": "Cryosphere",
#                         "prism:url": "https://api.elsevier.com/content/abstract/scopus_id/85105876022",
#                         "prism:volume": "14",
#                         "source-id": "11700154363",
#                         "subtype": "ar",
#                         "subtypeDescription": "Article"
#                   },
#                   {
#                         "@_fa": "true",
#                         "affiliation": [
#                               {
#                                     "@_fa": "true",
#                                     "affiliation-city": "Lisbon",
#                                     "affiliation-country": "Portugal",
#                                     "affilname": "Instituto Superior T\u00e9cnico"
#                               }
#                         ],
#                         "citedby-count": "1",
#                         "dc:creator": "Tenreiro T.",
#                         "dc:identifier": "SCOPUS_ID:85100430276",
#                         "dc:title": "Rethinking houses for wildland fire protection",
#                         "eid": "2-s2.0-85100430276",
#                         "link": [
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/abstract/scopus_id/85100430276",
#                                     "@ref": "self"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/abstract/scopus_id/85100430276?field=author,affiliation",
#                                     "@ref": "author-affiliation"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85100430276&origin=inward",
#                                     "@ref": "scopus"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85100430276&origin=inward",
#                                     "@ref": "scopus-citedby"
#                               }
#                         ],
#                         "openaccess": "0",
#                         "openaccessFlag": false,
#                         "prism:aggregationType": "Conference Proceeding",
#                         "prism:coverDate": "2020-01-01",
#                         "prism:coverDisplayDate": "2020",
#                         "prism:isbn": [
#                               {
#                                     "$": "9788409178711",
#                                     "@_fa": "true"
#                               }
#                         ],
#                         "prism:issn": "23868198",
#                         "prism:pageRange": "1937-1945",
#                         "prism:publicationName": "REHABEND",
#                         "prism:url": "https://api.elsevier.com/content/abstract/scopus_id/85100430276",
#                         "source-id": "21100826749",
#                         "subtype": "cp",
#                         "subtypeDescription": "Conference Paper"
#                   },
#                   {
#                         "@_fa": "true",
#                         "affiliation": [
#                               {
#                                     "@_fa": "true",
#                                     "affiliation-city": "Coimbra",
#                                     "affiliation-country": "Portugal",
#                                     "affilname": "Association for the Development of Industrial Aerodynamic"
#                               }
#                         ],
#                         "citedby-count": "21",
#                         "dc:creator": "Ribeiro L.M.",
#                         "dc:identifier": "SCOPUS_ID:85093476903",
#                         "dc:title": "Extreme wildfires and disasters around the world: Lessons to be learned",
#                         "eid": "2-s2.0-85093476903",
#                         "link": [
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/abstract/scopus_id/85093476903",
#                                     "@ref": "self"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/abstract/scopus_id/85093476903?field=author,affiliation",
#                                     "@ref": "author-affiliation"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85093476903&origin=inward",
#                                     "@ref": "scopus"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85093476903&origin=inward",
#                                     "@ref": "scopus-citedby"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/article/eid/3-s2.0-B9780128157213000023",
#                                     "@ref": "full-text"
#                               }
#                         ],
#                         "openaccess": "0",
#                         "openaccessFlag": false,
#                         "pii": "B9780128157213000023",
#                         "prism:aggregationType": "Book",
#                         "prism:coverDate": "2019-01-01",
#                         "prism:coverDisplayDate": "1 January 2019",
#                         "prism:doi": "10.1016/B978-0-12-815721-3.00002-3",
#                         "prism:isbn": [
#                               {
#                                     "$": "9780128157213",
#                                     "@_fa": "true"
#                               }
#                         ],
#                         "prism:pageRange": "31-51",
#                         "prism:publicationName": "Extreme Wildfire Events and Disasters: Root Causes and New Management Strategies",
#                         "prism:url": "https://api.elsevier.com/content/abstract/scopus_id/85093476903",
#                         "source-id": "21101023518",
#                         "subtype": "ch",
#                         "subtypeDescription": "Book Chapter"
#                   },
#                   {
#                         "@_fa": "true",
#                         "affiliation": [
#                               {
#                                     "@_fa": "true",
#                                     "affiliation-city": "Aberystwyth",
#                                     "affiliation-country": "United Kingdom",
#                                     "affilname": "Aberystwyth University"
#                               }
#                         ],
#                         "citedby-count": "35",
#                         "dc:creator": "Brown A.",
#                         "dc:identifier": "SCOPUS_ID:85055125491",
#                         "dc:title": "Appraisal of the Sentinel-1 &amp; 2 use in a large-scale wildfire assessment: A case study from Portugal's fires of 2017",
#                         "eid": "2-s2.0-85055125491",
#                         "freetoread": {
#                               "value": [
#                                     {
#                                           "$": "all"
#                                     },
#                                     {
#                                           "$": "repository"
#                                     },
#                                     {
#                                           "$": "repositoryam"
#                                     }
#                               ]
#                         },
#                         "freetoreadLabel": {
#                               "value": [
#                                     {
#                                           "$": "All Open Access"
#                                     },
#                                     {
#                                           "$": "Green"
#                                     }
#                               ]
#                         },
#                         "link": [
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/abstract/scopus_id/85055125491",
#                                     "@ref": "self"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/abstract/scopus_id/85055125491?field=author,affiliation",
#                                     "@ref": "author-affiliation"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85055125491&origin=inward",
#                                     "@ref": "scopus"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85055125491&origin=inward",
#                                     "@ref": "scopus-citedby"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/article/eid/1-s2.0-S0143622818305393",
#                                     "@ref": "full-text"
#                               }
#                         ],
#                         "openaccess": "0",
#                         "openaccessFlag": false,
#                         "pii": "S0143622818305393",
#                         "prism:aggregationType": "Journal",
#                         "prism:coverDate": "2018-11-01",
#                         "prism:coverDisplayDate": "November 2018",
#                         "prism:doi": "10.1016/j.apgeog.2018.10.004",
#                         "prism:issn": "01436228",
#                         "prism:pageRange": "78-89",
#                         "prism:publicationName": "Applied Geography",
#                         "prism:url": "https://api.elsevier.com/content/abstract/scopus_id/85055125491",
#                         "prism:volume": "100",
#                         "source-id": "27471",
#                         "subtype": "ar",
#                         "subtypeDescription": "Article"
#                   },
#                   {
#                         "@_fa": "true",
#                         "affiliation": [
#                               {
#                                     "@_fa": "true",
#                                     "affiliation-city": "Lisbon",
#                                     "affiliation-country": "Portugal",
#                                     "affilname": "Faculdade de Ci\u00eancias Sociais e Humanas da Universidade NOVA de Lisboa"
#                               }
#                         ],
#                         "citedby-count": "0",
#                         "dc:creator": "Poggi F.",
#                         "dc:identifier": "SCOPUS_ID:85051778462",
#                         "dc:title": "Municipal clusters of bioenergy: A contribution to forest fire prevention",
#                         "eid": "2-s2.0-85051778462",
#                         "freetoread": {
#                               "value": [
#                                     {
#                                           "$": "all"
#                                     },
#                                     {
#                                           "$": "publisherfullgold"
#                                     },
#                                     {
#                                           "$": "repository"
#                                     },
#                                     {
#                                           "$": "repositoryam"
#                                     }
#                               ]
#                         },
#                         "freetoreadLabel": {
#                               "value": [
#                                     {
#                                           "$": "All Open Access"
#                                     },
#                                     {
#                                           "$": "Gold"
#                                     },
#                                     {
#                                           "$": "Green"
#                                     }
#                               ]
#                         },
#                         "link": [
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/abstract/scopus_id/85051778462",
#                                     "@ref": "self"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/abstract/scopus_id/85051778462?field=author,affiliation",
#                                     "@ref": "author-affiliation"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85051778462&origin=inward",
#                                     "@ref": "scopus"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85051778462&origin=inward",
#                                     "@ref": "scopus-citedby"
#                               }
#                         ],
#                         "openaccess": "1",
#                         "openaccessFlag": true,
#                         "prism:aggregationType": "Journal",
#                         "prism:coverDate": "2018-01-01",
#                         "prism:coverDisplayDate": "2018",
#                         "prism:doi": "10.18055/Finis13717",
#                         "prism:issn": "04305027",
#                         "prism:issueIdentifier": "108",
#                         "prism:pageRange": "39-52",
#                         "prism:publicationName": "Finisterra",
#                         "prism:url": "https://api.elsevier.com/content/abstract/scopus_id/85051778462",
#                         "prism:volume": "53",
#                         "source-id": "28168",
#                         "subtype": "ar",
#                         "subtypeDescription": "Article"
#                   }
#             ],
#             "link": [
#                   {
#                         "@_fa": "true",
#                         "@href": "https://api.elsevier.com/content/search/scopus?start=0&count=25&query=TITLE-ABS-KEY+%28+%27pedrogao+AND+grande%27+%29+AND+PUBYEAR+%3E+2016+AND+PUBYEAR+%3C+2024&language=ENG",
#                         "@ref": "self",
#                         "@type": "application/json"
#                   },
#                   {
#                         "@_fa": "true",
#                         "@href": "https://api.elsevier.com/content/search/scopus?start=0&count=25&query=TITLE-ABS-KEY+%28+%27pedrogao+AND+grande%27+%29+AND+PUBYEAR+%3E+2016+AND+PUBYEAR+%3C+2024&language=ENG",
#                         "@ref": "first",
#                         "@type": "application/json"
#                   }
#             ],
#             "opensearch:Query": {
#                   "@role": "request",
#                   "@searchTerms": "TITLE-ABS-KEY ( 'pedrogao AND grande' ) AND PUBYEAR > 2016 AND PUBYEAR < 2024",
#                   "@startPage": "0"
#             },
#             "opensearch:itemsPerPage": "15",
#             "opensearch:startIndex": "0",
#             "opensearch:totalResults": "15"
#       }
# }

# %%
tabela_dados = pd.json_normalize(results["search-results"],['entry'] )
tabela_dados[:1]
# Out:
#    @_fa                                               link  \
# 0  true  [{'@_fa': 'true', '@ref': 'self', '@href': 'ht...
#
#                                            prism:url          dc:identifier  \
# 0  https://api.elsevier.com/content/abstract/scop...  SCOPUS_ID:85154552372
#
#                   eid                                           dc:title  \
# 0  2-s2.0-85154552372  The 2017 Extreme Wildfires Events in Portugal ...
#
#   dc:creator prism:publicationName prism:eIssn prism:volume  ...  \
# 0   Leone V.                  Fire    25716255            6  ...
#
#   subtypeDescription article-number    source-id openaccess openaccessFlag  \
# 0            Article            133  21101020133          1           True
#
#                              freetoread.value  \
# 0  [{'$': 'all'}, {'$': 'publisherfullgold'}]
#
#                        freetoreadLabel.value prism:issn  pii prism:isbn
# 0  [{'$': 'All Open Access'}, {'$': 'Gold'}]        NaN  NaN        NaN
#
# [1 rows x 29 columns]

# %% [markdown]
# #### Criação de tabela com o Pandas de colunas necessária

# %%
df_article = tabela_dados.loc[:,('dc:title', "prism:doi", 'dc:creator')]
df_article.rename(columns= {
                            'dc:title': 'title',
                            'prism:doi': 'doi',
                            'dc:creator': 'author'
                           }, 
                           inplace=True)
df_article
# Out:
#                                                 title  \
# 0   The 2017 Extreme Wildfires Events in Portugal ...
# 1   Multi-Indices Diagnosis of the Conditions That...
# 2   Field and laboratory analysis of the junction ...
# 3   Myopia during emergency improvisation: lessons...
# 4   Influence of Convectively Driven Flows in the ...
# 5   Sub-Hourly Precipitation Extremes in Mainland ...
# 6   The informative coverage of tragic events into...
# 7   The impact on structures of the pedrógão grand...
# 8   Lightning modelling for the research of forest...
# 9   When the sender is the message: the communicat...
# 10  Tracing devastating fires in Portugal to a sno...
# 11     Rethinking houses for wildland fire protection
# 12  Extreme wildfires and disasters around the wor...
# 13  Appraisal of the Sentinel-1 &amp; 2 use in a l...
# 14  Municipal clusters of bioenergy: A contributio...
#
#                                    doi        author
# 0                  10.3390/fire6040133      Leone V.
# 1                  10.3390/fire6020056    Andrade C.
# 2                      10.1071/WF22161   Viegas D.X.
# 3              10.1108/MD-03-2021-0378    Cunha M.P.
# 4                10.3390/atmos13030414      Pinto P.
# 5                  10.3390/cli10020028   Santos J.A.
# 6           10.15847/obsOBS15420211963    Ortiz S.L.
# 7                  10.3390/fire3040057  Ribeiro L.M.
# 8       10.1016/j.atmosres.2020.104993    Couto F.T.
# 9         10.17231/comsoc.0(2020).2741  Toniolo B.P.
# 10             10.5194/tc-14-3731-2020     Osmont D.
# 11                                 NaN   Tenreiro T.
# 12  10.1016/B978-0-12-815721-3.00002-3  Ribeiro L.M.
# 13        10.1016/j.apgeog.2018.10.004      Brown A.
# 14                 10.18055/Finis13717      Poggi F.

# %% [markdown]
# ## Pesquisa e recolha dos resumos com os DOIs

# %%
abs_list = []
for item in df_article['doi']:
    response_abst = requests.get("https://api.elsevier.com/content/abstract/doi/" + str(item),
                                 headers=headers, params={   })
    
    print(response_abst.url, 'status_code:', response_abst.status_code)

    if(response_abst.status_code == 200):
        results_abst = response_abst.json()
        if 'dc:description' in results_abst["abstracts-retrieval-response"][ "coredata"]:
            abs_list.append( results_abst["abstracts-retrieval-response"][ "coredata"]['dc:description'] )
        else:
            abs_list.append("NULL")
    else:
        abs_list.append("NULL")
print(f'total coletado: {len(abs_list)}')
# Out:
# https://api.elsevier.com/content/abstract/doi/10.3390/fire6040133 status_code: 200
# https://api.elsevier.com/content/abstract/doi/10.3390/fire6020056 status_code: 200
# https://api.elsevier.com/content/abstract/doi/10.1071/WF22161 status_code: 200
# https://api.elsevier.com/content/abstract/doi/10.1108/MD-03-2021-0378 status_code: 200
# https://api.elsevier.com/content/abstract/doi/10.3390/atmos13030414 status_code: 200
# https://api.elsevier.com/content/abstract/doi/10.3390/cli10020028 status_code: 200
# https://api.elsevier.com/content/abstract/doi/10.15847/obsOBS15420211963 status_code: 200
# https://api.elsevier.com/content/abstract/doi/10.3390/fire3040057 status_code: 200
# https://api.elsevier.com/content/abstract/doi/10.1016/j.atmosres.2020.104993 status_code: 200
# https://api.elsevier.com/content/abstract/doi/10.17231/comsoc.0(2020).2741 status_code: 200
# https://api.elsevier.com/content/abstract/doi/10.5194/tc-14-3731-2020 status_code: 200
# https://api.elsevier.com/content/abstract/doi/nan status_code: 404
# https://api.elsevier.com/content/abstract/doi/10.1016/B978-0-12-815721-3.00002-3 status_code: 200
# https://api.elsevier.com/content/abstract/doi/10.1016/j.apgeog.2018.10.004 status_code: 200
# https://api.elsevier.com/content/abstract/doi/10.18055/Finis13717 status_code: 200
# total coletado: 15

# %% [markdown]
# ### Concatenar os resumos com a tabela de artigos

# %%
abstracts= pd.DataFrame(abs_list, columns=['resumos'])
df_article = pd.concat([df_article, abstracts], axis=1)
df_article
# Out:
#                                                 title  \
# 0   The 2017 Extreme Wildfires Events in Portugal ...
# 1   Multi-Indices Diagnosis of the Conditions That...
# 2   Field and laboratory analysis of the junction ...
# 3   Myopia during emergency improvisation: lessons...
# 4   Influence of Convectively Driven Flows in the ...
# 5   Sub-Hourly Precipitation Extremes in Mainland ...
# 6   The informative coverage of tragic events into...
# 7   The impact on structures of the pedrógão grand...
# 8   Lightning modelling for the research of forest...
# 9   When the sender is the message: the communicat...
# 10  Tracing devastating fires in Portugal to a sno...
# 11     Rethinking houses for wildland fire protection
# 12  Extreme wildfires and disasters around the wor...
# 13  Appraisal of the Sentinel-1 &amp; 2 use in a l...
# 14  Municipal clusters of bioenergy: A contributio...
#
#                                    doi        author  \
# 0                  10.3390/fire6040133      Leone V.
# 1                  10.3390/fire6020056    Andrade C.
# 2                      10.1071/WF22161   Viegas D.X.
# 3              10.1108/MD-03-2021-0378    Cunha M.P.
# 4                10.3390/atmos13030414      Pinto P.
# 5                  10.3390/cli10020028   Santos J.A.
# 6           10.15847/obsOBS15420211963    Ortiz S.L.
# 7                  10.3390/fire3040057  Ribeiro L.M.
# 8       10.1016/j.atmosres.2020.104993    Couto F.T.
# 9         10.17231/comsoc.0(2020).2741  Toniolo B.P.
# 10             10.5194/tc-14-3731-2020     Osmont D.
# 11                                 NaN   Tenreiro T.
# 12  10.1016/B978-0-12-815721-3.00002-3  Ribeiro L.M.
# 13        10.1016/j.apgeog.2018.10.004      Brown A.
# 14                 10.18055/Finis13717      Poggi F.
#
#                                               resumos
# 0   This study aimed to explore differences in the...
# 1   Forest fires, though part of a natural forest ...
# 2   Background: Two fire ignitions in Pedrógão Gra...
# 3   Purpose: The purpose of this paper is to explo...
# 4   The influence of a mesoscale convective system...
# 5   Sub-hourly heavy precipitation events (SHHPs) ...
# 6   Dramatic events, natural catastrophes and, in ...
# 7   On 17 June 2017, one of the most dramatic and ...
# 8   The study aims to assess the applicability of ...
# 9   The theme of this article is the official cris...
# 10  Recent large wildfires, such as those in Portu...
# 11                                               NULL
# 12  In this chapter, the cases of the extreme wild...
# 13  The recent launch of Sentinel missions offers ...
# 14  After the shock that Portugal suffered with th...

# %%
symbols = ['<', '>', ':', '"', '/', '\\', '|', '?', '*']
query = ''.join([x for x in user_query if x not in symbols])
query
# Out:
# "TITLE-ABS-KEY ( 'pedrogao AND grande' ) AND PUBYEAR  2016 AND PUBYEAR  2024"

# %%
df_article.to_csv(path_data + query + '.csv', index=False)
